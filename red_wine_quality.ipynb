# %%
import pandas as pd
from pathlib import Path

data = pd.read_csv(Path("winequality-red.csv"))

# %%
from pandas.plotting import scatter_matrix

corr_matrix = data.corr()

corr_matrix.style.background_gradient(cmap="twilight")
# Out:
# <style type="text/css">
# #T_44d7f_row0_col0, #T_44d7f_row0_col5, #T_44d7f_row0_col8, #T_44d7f_row1_col1, #T_44d7f_row1_col2, #T_44d7f_row1_col9, #T_44d7f_row1_col11, #T_44d7f_row2_col1, #T_44d7f_row2_col2, #T_44d7f_row3_col3, #T_44d7f_row4_col4, #T_44d7f_row5_col5, #T_44d7f_row6_col6, #T_44d7f_row7_col7, #T_44d7f_row7_col10, #T_44d7f_row8_col0, #T_44d7f_row8_col3, #T_44d7f_row8_col4, #T_44d7f_row8_col8, #T_44d7f_row9_col9, #T_44d7f_row10_col6, #T_44d7f_row10_col7, #T_44d7f_row10_col10, #T_44d7f_row11_col11 {
#   background-color: #e2d9e2;
#   color: #000000;
# }
# #T_44d7f_row0_col1 {
#   background-color: #7195c0;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col2 {
#   background-color: #bd6e5a;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col3 {
#   background-color: #7398c1;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col4 {
#   background-color: #5f62b4;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col6 {
#   background-color: #b8c9d0;
#   color: #000000;
# }
# #T_44d7f_row0_col7 {
#   background-color: #ba6657;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col9 {
#   background-color: #5c389d;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col10, #T_44d7f_row3_col11 {
#   background-color: #5f5eb3;
#   color: #f1f1f1;
# }
# #T_44d7f_row0_col11, #T_44d7f_row7_col1, #T_44d7f_row10_col0 {
#   background-color: #5a2e93;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col0, #T_44d7f_row3_col4 {
#   background-color: #6173ba;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col3, #T_44d7f_row2_col5 {
#   background-color: #b5c7cf;
#   color: #000000;
# }
# #T_44d7f_row1_col4 {
#   background-color: #6171b9;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col5 {
#   background-color: #95b5c7;
#   color: #000000;
# }
# #T_44d7f_row1_col6 {
#   background-color: #647ebc;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col7 {
#   background-color: #5d3ca0;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col8 {
#   background-color: #41123d;
#   color: #f1f1f1;
# }
# #T_44d7f_row1_col10 {
#   background-color: #6e92c0;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col0 {
#   background-color: #c1775f;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col3, #T_44d7f_row3_col9, #T_44d7f_row4_col6 {
#   background-color: #6a8bbf;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col4, #T_44d7f_row11_col8 {
#   background-color: #5a2d92;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col6 {
#   background-color: #6d90c0;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col7 {
#   background-color: #531545;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col8, #T_44d7f_row9_col3 {
#   background-color: #b3c6ce;
#   color: #000000;
# }
# #T_44d7f_row2_col9 {
#   background-color: #3d114e;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col10, #T_44d7f_row6_col1 {
#   background-color: #521c79;
#   color: #f1f1f1;
# }
# #T_44d7f_row2_col11 {
#   background-color: #421257;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col0 {
#   background-color: #371143;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col1 {
#   background-color: #5c359a;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col2, #T_44d7f_row5_col8 {
#   background-color: #411254;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col5 {
#   background-color: #5f5bb2;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col6, #T_44d7f_row6_col0 {
#   background-color: #5d41a3;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col7 {
#   background-color: #4f1444;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col8 {
#   background-color: #5c369b;
#   color: #f1f1f1;
# }
# #T_44d7f_row3_col10 {
#   background-color: #5c3499;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col0, #T_44d7f_row9_col11 {
#   background-color: #3b114a;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col1, #T_44d7f_row9_col10 {
#   background-color: #552081;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col2 {
#   background-color: #33113c;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col3 {
#   background-color: #91b2c6;
#   color: #000000;
# }
# #T_44d7f_row4_col5 {
#   background-color: #8cafc5;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col7 {
#   background-color: #3a1148;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col8, #T_44d7f_row5_col9 {
#   background-color: #6277bb;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col9, #T_44d7f_row11_col2 {
#   background-color: #2f1436;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col10 {
#   background-color: #7499c1;
#   color: #f1f1f1;
# }
# #T_44d7f_row4_col11, #T_44d7f_row9_col1 {
#   background-color: #7297c1;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col0 {
#   background-color: #5e4fac;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col1 {
#   background-color: #5d3a9e;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col2, #T_44d7f_row5_col7 {
#   background-color: #5e4eab;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col3 {
#   background-color: #6275ba;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col4, #T_44d7f_row11_col7 {
#   background-color: #6989be;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col6 {
#   background-color: #a94850;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col10 {
#   background-color: #5f61b4;
#   color: #f1f1f1;
# }
# #T_44d7f_row5_col11 {
#   background-color: #6379bb;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col2, #T_44d7f_row6_col7 {
#   background-color: #59288d;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col3 {
#   background-color: #606db8;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col4 {
#   background-color: #6278bb;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col5 {
#   background-color: #a44250;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col8 {
#   background-color: #5b3095;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col9, #T_44d7f_row8_col11 {
#   background-color: #637bbc;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col10, #T_44d7f_row8_col5 {
#   background-color: #6f93c0;
#   color: #f1f1f1;
# }
# #T_44d7f_row6_col11 {
#   background-color: #86aac4;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col0 {
#   background-color: #c0765f;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col2 {
#   background-color: #5d1749;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col3, #T_44d7f_row11_col9 {
#   background-color: #511b77;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col4 {
#   background-color: #5b2f94;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col5, #T_44d7f_row8_col6 {
#   background-color: #9cb9c8;
#   color: #000000;
# }
# #T_44d7f_row7_col6 {
#   background-color: #6580bd;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col8 {
#   background-color: #6c8fbf;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col9 {
#   background-color: #5e49a9;
#   color: #f1f1f1;
# }
# #T_44d7f_row7_col11 {
#   background-color: #81a6c3;
#   color: #f1f1f1;
# }
# #T_44d7f_row8_col1 {
#   background-color: #311337;
#   color: #f1f1f1;
# }
# #T_44d7f_row8_col2 {
#   background-color: #e0d9e2;
#   color: #000000;
# }
# #T_44d7f_row8_col7 {
#   background-color: #a4beca;
#   color: #000000;
# }
# #T_44d7f_row8_col9 {
#   background-color: #cbd2d7;
#   color: #000000;
# }
# #T_44d7f_row8_col10 {
#   background-color: #381145;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col0 {
#   background-color: #341238;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col2 {
#   background-color: #481341;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col4 {
#   background-color: #301437;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col5 {
#   background-color: #769cc1;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col6 {
#   background-color: #6b8dbf;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col7 {
#   background-color: #481563;
#   color: #f1f1f1;
# }
# #T_44d7f_row9_col8 {
#   background-color: #5f5fb3;
#   color: #f1f1f1;
# }
# #T_44d7f_row10_col1 {
#   background-color: #6683bd;
#   color: #f1f1f1;
# }
# #T_44d7f_row10_col2 {
#   background-color: #4a1566;
#   color: #f1f1f1;
# }
# #T_44d7f_row10_col3 {
#   background-color: #99b8c8;
#   color: #000000;
# }
# #T_44d7f_row10_col4 {
#   background-color: #d5d6dc;
#   color: #000000;
# }
# #T_44d7f_row10_col5 {
#   background-color: #bbcad1;
#   color: #000000;
# }
# #T_44d7f_row10_col8 {
#   background-color: #39113a;
#   color: #f1f1f1;
# }
# #T_44d7f_row10_col9 {
#   background-color: #5f64b5;
#   color: #f1f1f1;
# }
# #T_44d7f_row10_col11 {
#   background-color: #721d4f;
#   color: #f1f1f1;
# }
# #T_44d7f_row11_col0 {
#   background-color: #351140;
#   color: #f1f1f1;
# }
# #T_44d7f_row11_col1 {
#   background-color: #a3beca;
#   color: #000000;
# }
# #T_44d7f_row11_col3 {
#   background-color: #adc3cd;
#   color: #000000;
# }
# #T_44d7f_row11_col4 {
#   background-color: #a1bdc9;
#   color: #000000;
# }
# #T_44d7f_row11_col5 {
#   background-color: #afc4cd;
#   color: #000000;
# }
# #T_44d7f_row11_col6 {
#   background-color: #ddd9e0;
#   color: #000000;
# }
# #T_44d7f_row11_col10 {
#   background-color: #842550;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44d7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44d7f_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_44

# %% [markdown]
# There seems to be no correlation between quality and:
# - pH
# - free sulfur dioxide
# - residual sugar
# - fixed acidity

# %%
import numpy as np

# mark quality as either bad (0) or good (1)
data["quality"] = np.where(data["quality"] > 5, 1, 0)

data = data.drop("pH", axis=1)
data = data.drop("free sulfur dioxide", axis=1)
data = data.drop("residual sugar", axis=1)

# %%
from sklearn.model_selection import train_test_split

x = data.drop("quality", axis=1)
y = data["quality"]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, shuffle=True, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

lr = LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)

lr_predict = lr.predict(x_test)
lr_conf_matrix = confusion_matrix(y_test, lr_predict)
lr_acc_score = accuracy_score(y_test, lr_predict)

print(lr_conf_matrix)
print(lr_acc_score)
# Out:
# [[109  32]
#  [ 48 131]]
# 0.75

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
dt_predict = dt.predict(x_test)

dt_conf_matrix = confusion_matrix(y_test, dt_predict)
dt_acc_score = accuracy_score(y_test, dt_predict)
print(dt_conf_matrix)
print(dt_acc_score)
# Out:
# [[ 94  47]
#  [ 46 133]]
# 0.709375

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(x_train, y_train)
nb_predict = nb.predict(x_test)
nb_conf_matrix = confusion_matrix(y_test, nb_predict)
nb_acc_score = accuracy_score(y_test, nb_predict)
print(nb_conf_matrix)
print(nb_acc_score)
# Out:
# [[102  39]
#  [ 44 135]]
# 0.740625

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_features="sqrt")
rf.fit(x_train, y_train)
rf_predict = rf.predict(x_test)

rf_conf_matrix = confusion_matrix(y_test, rf_predict)
rf_acc_score = accuracy_score(y_test, rf_predict)
print(rf_conf_matrix)
print(rf_acc_score)
# Out:
# [[108  33]
#  [ 32 147]]
# 79.6875

# %%
from sklearn.svm import SVC

rbf_svc = SVC(kernel="rbf")
rbf_svc.fit(x_train, y_train)
rbf_svc = rf.predict(x_test)
rbf_svc_conf_matrix = confusion_matrix(y_test, rf_predict)
rbf_svc_acc_score = accuracy_score(y_test, rf_predict)
print(rbf_svc_conf_matrix)
print(rbf_svc_acc_score)
# Out:
# [[108  33]
#  [ 32 147]]
# 79.6875

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
sgd_predict = sgd.predict(x_test)
sgd_conf_matrix = confusion_matrix(y_test, sgd_predict)
sgd_acc_score = accuracy_score(y_test, sgd_predict)
print(sgd_conf_matrix)
print(sgd_acc_score)
# Out:
# [[ 54  87]
#  [ 18 161]]
# 0.671875

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
knn_predict = knn.predict(x_test)

knn_conf_matrix = confusion_matrix(y_test, knn_predict)
knn_acc_score = accuracy_score(y_test, knn_predict)

print(knn_conf_matrix)
print(knn_acc_score)
# Out:
# [[ 95  46]
#  [ 42 137]]
# 0.725
